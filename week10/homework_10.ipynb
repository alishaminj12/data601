# %%
### DON'T CHANGE THIS CELL
import os

class FileProcessor:
    
    def __init__(self, path, file_types=['.ipynb']):
        self.files = self.find_all_files(path, file_types)
        print(f'{len(self.files)} file(s) found...')

    
    def find_all_files(self, path, file_types):
        paths = []
        for root, dirs, files in os.walk(path):
            for file in files:
                if any([file.endswith(ft) for ft in file_types]):
                    path = os.path.join(root, file)
                    # print(path)
                    paths.append(path)
        return paths
    
    def read_file(self, file_path, encoding='utf8'):
        with open(file_path,encoding=encoding) as f:
            return f.read()
    
    def start(self):
        """
        Entry point for the class
        """
        for file in self.files:
            self.process_file(file)
        
    def process_file(self, file_path):
        """
        abstract method
        """
        raise NotImplemented('process_file method not implemented')

# %%
import os, sys

# %%
path = "C:\\Users\\HP\\OneDrive\\Documents\\GitHub\\data601"
dirs = os.listdir( path )

# %%
for file in dirs:
   print(file)
# Out:
# .git
# .gitignore
# .ipynb_checkpoints
# Midterm
# notes
# README.md
# week01
# week02
# week03
# week04
# week06
# week07
# week08
# week09
# week10
# week_05
# WG56858

# %%
class ModuleLister(FileProcessor):
    
    def __init__(self, path):
        
        super().__init__(path)
        #path = "C:\\Users\\HP\\OneDrive\\Documents\\GitHub\\data601"
        #dirs = os.listdir( path )
        
        #for file in dirs:
            #print(file)
            
        
    def process_file(self, file_path):
        file = processor.read_file(file_path)
        split_fn = file.split(',')
        for i in range(len(split_fn)):
            if 'import' in split_fn[i]:
                mod = split_fn[i].split('import')
                print(mod[len(mod)-1])
                
    def process_path(self, file_path):
        try:
            content = self.read_file(file_path)

            if 'token' in content:
                print(file_path, 'module lister')
        
        except Exception as e:
            print('--- ERRROR', file_path, str(e))
                
    
    pass

# %%
processor = ModuleLister(path=r'C:\Users\HP\OneDrive\Documents\GitHub\data601')
# Out:
# 79 file(s) found...

# %%
processor.start()
# Out:
# ing libraries\n"
#  pandas as pd\n"
#  matplotlib.pylab as plt\n"
#  missingno as msno\n"
#  seaborn as sns\n"
#  time\n"
# ing libraries\n"
#  pandas as pd\n"
#  matplotlib.pylab as plt\n"
#  missingno as msno\n"
#  seaborn as sns\n"
#  time\n"
#  fuzzywuzzy"
#    ]
#   }
# \u001b \u001bfuzz\u001b\u001b\u001b\u001b\u001b\u001b\n\u001b\u001b      2\u001b \u001b\u001b\u001b\n\u001b      3\u001b \u001bfuzz\u001b\u001b.\u001b\u001bratio\u001b\u001b(\u001b\u001b\"this is DATA 601\"\u001b\u001b
#  fuzz\n"
#  random \n"
#  matplotlib.pyplot as plt\n"
#  random \n"
#  matplotlib.pyplot as plt\n"
#  pandas as pd\n"
#  matplotlib.pyplot as plt\n"
#  matplotlib.pyplot as plt\n"
#  Faker\n"
#  faker\n"
#  pandas as pd\n"
#  random\n"
#  numpy as np\n"
#  sys\n"
#  seaborn as sns\n"
#  choices\n"
#  pyplot as plt"
#    ]
#   }
#  names\n"
#  random\n"
#  operator\n"
#  operator\n"
#  random\n"
#  randint\n"
#  operator\n"
#  random\n"
#  operator as op\n"
#  random\n"
#  datetime\n"
#  date\n"
#  re\n"
#  pandas as pd\n"
#  Faker\n"
#  faker\n"
#  pandas as pd\n"
#  random\n"
#  numpy as np\n"
#  sys\n"
#  seaborn as sns\n"
#  choices\n"
#  pyplot as plt"
#    ]
#   }
#  names\n"
#  pandas as pd\n"
#  matplotlib.pyplot as plt\n"
#  numpy as np\n"
#  datetime\n"
#  time\n"
#  seaborn as sn"
#    ]
#   }
#  pandas\n"
#  pandas as pd\n"
#  matplotlib.pyplot as plt"
#    ]
#   }
#  pandas as pd \n"
#  request"
#    ]
#   }
#  pandas as pd\n"
#  csv\n"
#  csv\n"
#  pyplot as plt\n"
#  Counter\n"
#  request"
#    ]
#   }
#  pandas as pd\n"
#  csv\n"
#  csv\n"
#  pyplot as plt\n"
#  Counter\n"
#  request"
#    ]
#   }
#  pandas as pd\n"
#  csv\n"
#  csv\n"
#  pyplot as plt\n"
#  Counter\n"
#  request "
#    ]
#   }
#  pandas as pd\n"
#  csv\n"
#  matplotlib.pyplot as plt\n"
#  pandas as pd\n"
#  csv\n"
#  collections\n"
#  request"
#    ]
#   }
#  pandas as pd\n"
#  csv\n"
#  csv\n"
#  pyplot as plt\n"
#  Counter\n"
#  ZipFile\n"
#  seaborn as sns\n"
#  pandas as pd"
#    ]
#   }
#  request\n"
#  request"
#    ]
#   }
#  pandas as pd\n"
#  csv\n"
#  pyplot as plt\n"
#  Counter\n"
#  request"
#    ]
#   }
#  pandas as pd\n"
#  csv\n"
#  csv\n"
#  pyplot as plt\n"
#  Counter\n"
#  request"
#    ]
#   }
#  pandas as pd\n"
#  csv\n"
#  csv\n"
#  pyplot as plt\n"
#  Counter\n"
#  request"
#    ]
#   }
#  pandas as pd\n"
#  csv\n"
#  csv\n"
#  pyplot as plt\n"
#  Counter\n"
#  ZipFile"
#    ]
#   }
#  request\n"
#  Faker\n"
#  faker\n"
#  pandas as pd\n"
#  random\n"
#  numpy as np\n"
#  sys"
#    ]
#   }
# \u001b \u001burllib\u001b\u001b.\u001b\u001brequest\u001b\u001b\u001b\u001b\u001b\u001b\n\u001b    211\u001b \u001b\u001b\u001b\n\u001b--> 212\u001b     \u001breturn\u001b \u001burllib\u001b\u001b.\u001b\u001brequest\u001b\u001b.\u001b\u001burlopen\u001b\u001b(\u001b\u001b*\u001b\u001bargs\u001b\u001b
# \u001b \u001burllib\u001b\u001b.\u001b\u001brequest\u001b\u001b\u001b\u001b\u001b\u001b\n\u001b    211\u001b \u001b\u001b\u001b\n\u001b--> 212\u001b     \u001breturn\u001b \u001burllib\u001b\u001b.\u001b\u001brequest\u001b\u001b.\u001b\u001burlopen\u001b\u001b(\u001b\u001b*\u001b\u001bargs\u001b\u001b
# \u001b \u001burllib\u001b\u001b.\u001b\u001brequest\u001b\u001b\u001b\u001b\u001b\u001b\n\u001b    211\u001b \u001b\u001b\u001b\n\u001b--> 212\u001b     \u001breturn\u001b \u001burllib\u001b\u001b.\u001b\u001brequest\u001b\u001b.\u001b\u001burlopen\u001b\u001b(\u001b\u001b*\u001b\u001bargs\u001b\u001b
# \u001b \u001burllib\u001b\u001b.\u001b\u001brequest\u001b\u001b\u001b\u001b\u001b\u001b\n\u001b    211\u001b \u001b\u001b\u001b\n\u001b--> 212\u001b     \u001breturn\u001b \u001burllib\u001b\u001b.\u001b\u001brequest\u001b\u001b.\u001b\u001burlopen\u001b\u001b(\u001b\u001b*\u001b\u001bargs\u001b\u001b
#  Faker\n"
#  faker\n"
#  pandas as pd\n"
#  random\n"
#  numpy as np\n"
#  sys\n"
#  seaborn as sns\n"
#  pyplot as plt\n"
#  numpy as np"
#    ]
#   }
#  matplotlib.pyplot as plt\n"
#  Faker\n"
#  faker\n"
#  pandas as pd\n"
#  random\n"
#  numpy as np\n"
#  sys\n"
#  seaborn as sns\n"
#  pyplot as plt\n"
#    ]
#   }
# \u001b \u001bget_grouper\u001b\u001b\u001b\u001b\u001b\u001b\n\u001b    888\u001b \u001b\u001b\u001b\n\u001b--> 889\u001b             grouper
#  Faker\n"
#  faker\n"
#  pandas as pd\n"
#  random\n"
#  numpy as np\n"
#  sys\n"
#  seaborn as sns\n"
#  choices\n"
#  pyplot as plt"
#    ]
#   }
#  names\n"
#  Faker\n"
#  faker\n"
#  pandas as pd\n"
#  random\n"
#  numpy as np\n"
#  sys\n"
#  seaborn as sns\n"
#  choices\n"
#  pyplot as plt\n"
#    ]
#   }
#  faker.providers.person.Provider\n"
#  names\n"
# \u001b \u001bnumpy\u001b\u001b.\u001b\u001bma\u001b\u001b.\u001b\u001bmrecords\u001b \u001bas\u001b \u001bmrecords\u001b\u001b\u001b\u001b\u001b\u001b\n"
# \u001b \u001bmerge\u001b\u001b\u001b\u001b\u001b\u001b\n\u001b   9189\u001b \u001b\u001b\u001b\n\u001b-> 9190\u001b         return merge(\n\u001b\u001b   9191\u001b             \u001bself\u001b\u001b
# \u001b \u001bmerge\u001b\u001b\u001b\u001b\u001b\u001b\n\u001b   9189\u001b \u001b\u001b\u001b\n\u001b-> 9190\u001b         return merge(\n\u001b\u001b   9191\u001b             \u001bself\u001b\u001b
# \u001b \u001bget_grouper\u001b\u001b\u001b\u001b\u001b\u001b\n\u001b    888\u001b \u001b\u001b\u001b\n\u001b--> 889\u001b             grouper
#  Faker\n"
#  faker\n"
#  pandas as pd\n"
#  random\n"
#  numpy as np\n"
#  sys\n"
#  seaborn as sns\n"
#  choices\n"
#  pyplot as plt"
#    ]
#   }
#  names\n"
#  pandas as pd\n"
# ant part of your role at work: (Select all that apply) - Other - Text\n"
#  re"
#    ]
#   }
# ance\n"
#  data by insta...\n"
#  Faker\n"
#  faker\n"
#  pandas as pd\n"
#  random\n"
#  numpy as np\n"
#  sys\n"
#  pyplot as plt\n"
#  numpy as np"
#    ]
#   }
#  seaborn\n"
#  seaborn as sns\n"
#  pyplot as plt\n"
#  numpy\n"
#  numpy as np"
#    ]
#   }
#  matplotlib.pyplot as plt\n"
#  Faker\n"
#  faker\n"
#  pandas as pd\n"
#  random\n"
#  numpy as np\n"
#  sys\n"
#  seaborn\n"
#  seaborn as sns\n"
#  pyplot as plt\n"
#  numpy\n"
#  numpy as np"
#    ]
#   }
# \u001b \u001bget_grouper\u001b\u001b\u001b\u001b\u001b\u001b\n\u001b    888\u001b \u001b\u001b\u001b\n\u001b--> 889\u001b             grouper
# \u001b \u001bget_grouper\u001b\u001b\u001b\u001b\u001b\u001b\n\u001b    888\u001b \u001b\u001b\u001b\n\u001b--> 889\u001b             grouper
#  Faker\n"
#  faker\n"
#  pandas as pd\n"
#  random\n"
#  numpy as np\n"
#  sys\n"
#  seaborn as sns\n"
#  choices\n"
#  pyplot as plt"
#    ]
#   }
#  names\n"
#  pandas as pd\n"
#  re"
#    ]
#   }
#  pandas as pd\n"
#  re\n"
#  numpy as np"
#    ]
#   }
#  pandas as pd\n"
#  re"
#    ]
#   }
# \u001b \u001bdatetime\u001b\u001b\u001b\u001b\u001b\u001b\n\u001b      2\u001b \u001bdatestring\u001b \u001b=\u001b \u001b'05-06-1984'\u001b \u001b# 2012 / 12 /12\u001b\u001b\u001b\u001b\u001b\u001b\n\u001b----> 3\u001b \u001bdatetime\u001b\u001b.\u001b\u001bstrptime\u001b\u001b(\u001b\u001bdatestring\u001b\u001b
#  datetime\n"
#  pandas as pd\n"
# an...</td>\n"
# an...   \n"
# ant part of your role at work: (Select all that apply) - Other - Text\n"
#  re"
#    ]
#   }
# ance\n"
#  data by installing packages and then easily we can analyse data in structuredformat\n"
#  pandas as pd\n"
#  re"
#    ]
#   }
#  urlopen\n"
#  re\n"
#  pandas as pd\n"
#  re"
#    ]
#   }
#  pandas as pd\n"
#  re"
#    ]
#   }
#  pandas as pd\n"
#  re"
#    ]
#   }
#  pandas as pd\n"
#  re"
#    ]
#   }
#  pandas as pd\n"
#  re"
#    ]
#   }
#  pandas as pd\n"
# an...</td>\n"
# an...   \n"
# ant part of your role at work: (Select all that apply) - Other - Text\n"
#  re"
#    ]
#   }
#  pandas as pd\n"
#  re"
#    ]
#   }
#  pandas as pd"
#    ]
#   }
#  pandas as pd\n"
# ant part of your role at work: (Select all that apply) - Other - Text\n"
#  re"
#    ]
#   }
#  pandas as pd\n"
#  re"
#    ]
#   }
#  pandas as pd\n"
#  matplotlib\n"
#  matplotlib.pyplot as plt"
#    ]
#   }
#  Firefox
#  browserhistory as bh"
#    ]
#   }
#  pandas as pd"
#    ]
#   }
#  urlparse\n"
#  pandas as pd\n"
#  matplotlib\n"
#  matplotlib.pyplot as plt"
#    ]
#   }
#  Firefox
#  pandas as pd\n"
#  matplotlib\n"
#  matplotlib.pyplot as plt"
#    ]
#   }
#  os\n"
#  os
# ' in y[i]:\n"
# ')\n"
#  os\n"
#  os
# ' in split_fun[i]:\n"
# ')\n"
#  os\n"
#  modulefinder
# _hook(self
# _hook(self
#  pandas as pd\n"
#  matplotlib\n"
#  matplotlib.pyplot as plt"
#    ]
#   }
#  os\n"
#  os
# ' in y[i]:\n"
# ')\n"
#  os\n"
#  modulefinder
# _hook(self
# _hook(self
#  pandas as pd\n"
#  seaborn\n"
#  seaborn as sns\n"
#  pyplot as plt\n"
#  numpy\n"
#  numpy as np"
#    ]
#   }
#  seaborn as sns\n"
#  pandas as pd\n"
