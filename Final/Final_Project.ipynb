# %% [markdown]
# #         Prices Analysis for Car Models

# %% [markdown]
#                                                                                     - Alisha Minj (WG56858)

# %% [markdown]
# ## Introduction
#
# The dataset contains the production and manufacturing of autommobile in the US. It contains the factors affecting the price of Cars. To understand variables that are significant in predicting the price of a car and what describe the price of a car. The second dataset contains the used cars in the US, that is kept on an online Auction.
#
# Cars has become the necessity in todays world. We all have different tastes when it comes to owning a car or at least when thinking of owning one. Some fit in our budget and some lauxury brands are heavy on pockets. So, People do take used car into consideration.

# %% [markdown]
# ## Hypothesis:
#
# - Is Auction car prices, on average, 20 percent less than those of a private seller or used car dealer.
#
# 1. Determining the Mileage ,Engine and Power of the used cars, to check if the Auction Price is justifiable.
# 2. Popular Car Brands and its model type.
# 3. Which States hold and prefer used cars in auction?
#
# ## Observation
#
# - Generally, the prices in the auction will be less as it is the used cars

# %% [markdown]
# ### Datasets Used :
#
# 1.    Car Price Prediction
#     - Source : https://www.kaggle.com/code/hellbuoy/carprice-prediction-mlr-rfe-vif/notebook
#     - Shape of Dataset : (205, 26)
#
#
# 2.   US Cars Dataset
#     - Source : https://www.kaggle.com/datasets/doaaalsenani/usa-cers-dataset
#     - Shape of Dataset : (2499, 13)

# %% [markdown]
# ## Intial Requirements

# %%
#install library to check missing values
# !pip install missingno
# Out:
# Requirement already satisfied: missingno in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (0.5.1)
# Requirement already satisfied: scipy in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from missingno) (1.8.0)
# Requirement already satisfied: numpy in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from missingno) (1.22.3)
# Requirement already satisfied: matplotlib in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from missingno) (3.5.1)
# Requirement already satisfied: seaborn in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from missingno) (0.11.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->missingno) (3.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->missingno) (4.30.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->missingno) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->missingno) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->missingno) (1.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: pandas>=0.23 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from seaborn->missingno) (1.4.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.23->seaborn->missingno) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)

# %%
#importing libraries
import pandas as pd
import matplotlib.pylab as plt
import missingno as msno
import numpy as np
import seaborn as sns
import re
print('Pandas',pd.__version__)
# Out:
# Pandas 1.3.4

# %% [markdown]
# ## Dataset 1

# %%
#read the data file
Car = pd.read_csv('CarPrice_Assignment.csv')
Car.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %%
#check the number of rows and columns in the dataframe
Car.shape
# Out:
# (205, 26)

# %% [markdown]
# ## CleanUp, Sanity check and removal of Data Inconsistencies

# %%
#Find number of non-null values and data type of each column in the dataframe
Car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %%
# describe of the data
Car.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# 25%    2145.000000   97.000000    3.150000    3.110000          8.600000
# 50%    2414.000000  120.000000    3.310000    3.290000          9.000000
# 75%    2935.000000  141.000000    3.580000    3.410000          9.400000
# max    4066.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakrpm     citympg  highwaympg         price
# count  205.000000   205.000000  205.000000  205.000000    205.000000
# mean   104.117073  5125.121951   25.219512   30.751220  13276.710571
# std     39.544167   476.985643    6.542142    6.886443   7988.852332
# min     48.000000  4150.000000   13.000000   16.000000   5118.000000
# 25%     70.000000  4800.000000   19.000000   25.000000   7788.000000
# 50%     95.000000  5200.000000   24.000000   30.000000  10295.000000
# 75%    116.000000  5500.000000   30.000000   34.000000  16503.000000
# max    288.000000  6600.000000   49.000000   54.000000  45400.000000

# %% [markdown]
# Now we check whether there are any columns that have same value for all the rows

# %%
counter = 0
for this_column in Car.columns:
    if (Car[this_column].nunique()==1):
        print(this_column)
        counter = 1
if(counter != 1):
    print('There are no such columns having the same value for all the rows.')
# Out:
# There are no such columns having the same value for all the rows.

# %% [markdown]
# Now lets get the number of uniques values per column and their counts

# %%
#function to number of unique values and its count for all columns in a data frame
def uniq_per_col(df,count):
    for this_column in df.columns:
        print("==== ",this_column,"has",df[this_column].nunique(),"unique entries ====")
        print(df[this_column].value_counts().head(count))

# %%
uniq_per_col(Car,5)
# Out:
# ====  car_ID has 205 unique entries ====
# 1      1
# 142    1
# 132    1
# 133    1
# 134    1
# Name: car_ID, dtype: int64
# ====  symboling has 6 unique entries ====
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# Name: symboling, dtype: int64
# ====  CarName has 147 unique entries ====
# toyota corona           6
# toyota corolla          6
# peugeot 504             6
# subaru dl               4
# mitsubishi mirage g4    3
# Name: CarName, dtype: int64
# ====  fueltype has 2 unique entries ====
# gas       185
# diesel     20
# Name: fueltype, dtype: int64
# ====  aspiration has 2 unique entries ====
# std      168
# turbo     37
# Name: aspiration, dtype: int64
# ====  doornumber has 2 unique entries ====
# four    115
# two      90
# Name: doornumber, dtype: int64
# ====  carbody has 5 unique entries ====
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: carbody, dtype: int64
# ====  drivewheel has 3 unique entries ====
# fwd    120
# rwd     76
# 4wd      9
# Name: drivewheel, dtype: int64
# ====  enginelocation has 2 unique entries ====
# front    202
# rear       3
# Name: enginelocation, dtype: int64
# ====  wheelbase has 53 unique entries ====
# 94.5    21
# 93.7    20
# 95.7    13
# 96.5     8
# 97.3     7
# Name: wheelbase, dtype: int64
# ====  carlength has 75 unique entries ====
# 157.3    15
# 188.8    11
# 171.7     7
# 186.7     7
# 166.3     7
# Name: carlength, dtype: int64
# ====  carwidth has 44 unique entries ====
# 63.8    24
# 66.5    23
# 65.4    15
# 63.6    11
# 64.4    10
# Name: carwidth, dtype: int64
# ====  carheight has 49 unique entries ====
# 50.8    14
# 52.0    12
# 55.7    12
# 54.1    10
# 54.5    10
# Name: carheight, dtype: int64
# ====  curbweight has 171 unique entries ====
# 2385    4
# 1918    3
# 2275    3
# 1989    3
# 2410    2
# Name: curbweight, dtype: int64
# ====  enginetype has 7 unique entries ====
# ohc     148
# ohcf     15
# ohcv     13
# dohc     12
# l        12
# Name: enginetype, dtype: int64
# ====  cylindernumber has 7 unique entries ====
# four     159
# six       24
# five      11
# eight      5
# two        4
# Name: cylindernumber, dtype: int64
# ====  enginesize has 44 unique entries ====
# 122    15
# 92     15
# 97     14
# 98     14
# 108    13
# Name: enginesize, dtype: int64
# ====  fuelsystem has 8 unique entries ====
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# Name: fuelsystem, dtype: int64
# ====  boreratio has 38 unique entries ====
# 3.62    23
# 3.19    20
# 3.15    15
# 3.03    12
# 2.97    12
# Name: boreratio, dtype: int64
# ====  stroke has 37 unique entries ====
# 3.40    20
# 3.23    14
# 3.15    14
# 3.03    14
# 3.39    13
# Name: stroke, dtype: int64
# ====  compressionratio has 32 unique entries ====
# 9.0    46
# 9.4    26
# 8.5    14
# 9.5    13
# 9.3    11
# Name: compressionratio, dtype: int64
# ====  horsepower has 59 unique entries ====
# 68     19
# 70     11
# 69     10
# 116     9
# 110     8
# Name: horsepower, dtype: int64
# ====  peakrpm has 23 unique entries ====
# 5500    37
# 4800    36
# 5000    27
# 5200    23
# 5400    13
# Name: peakrpm, dtype: int64
# ====  citympg has 29 unique entries ====
# 31    28
# 19    27
# 24    22
# 27    14
# 17    13
# Name: citympg, dtype: int64
# ====  highwaympg has 30 unique entries ====
# 25    19
# 38    17
# 24    17
# 30    16
# 32    16
# Name: highwaympg, dtype: int64
# ====  price has 189 unique entries ====
# 8921.0    2
# 9279.0    2
# 7898.0    2
# 8916.5    2
# 7775.0    2
# Name: price, dtype: int64

# %% [markdown]
# Now lets find the percentage of null values in each column

# %%
Car.isnull().sum()/len(Car)*100
# Out:
# car_ID              0.0
# symboling           0.0
# CarName             0.0
# fueltype            0.0
# aspiration          0.0
# doornumber          0.0
# carbody             0.0
# drivewheel          0.0
# enginelocation      0.0
# wheelbase           0.0
# carlength           0.0
# carwidth            0.0
# carheight           0.0
# curbweight          0.0
# enginetype          0.0
# cylindernumber      0.0
# enginesize          0.0
# fuelsystem          0.0
# boreratio           0.0
# stroke              0.0
# compressionratio    0.0
# horsepower          0.0
# peakrpm             0.0
# citympg             0.0
# highwaympg          0.0
# price               0.0
# dtype: float64

# %% [markdown]
# From the above observation it is clear that, we have a good variety of data and have eliminated various data inconsistencies that would be there. We have minimal null values in the data. Hence we can conclude that we have good data. But we still can work on the data types of object type columns.

# %%
#find number of unique values in various object type columns
count = 10
for col,col_type in Car.dtypes.iteritems():
    if(col_type=='object'):
        print('\n',col,'has',Car[col].nunique(),'unique entries; and the top unique values are ')
        print(Car[col].value_counts().head(count))
# Out:
#  CarName has 147 unique entries; and the top unique values are
# toyota corona           6
# toyota corolla          6
# peugeot 504             6
# subaru dl               4
# mitsubishi mirage g4    3
# mazda 626               3
# toyota mark ii          3
# mitsubishi outlander    3
# mitsubishi g4           3
# honda civic             3
# Name: CarName, dtype: int64
#
#  fueltype has 2 unique entries; and the top unique values are
# gas       185
# diesel     20
# Name: fueltype, dtype: int64
#
#  aspiration has 2 unique entries; and the top unique values are
# std      168
# turbo     37
# Name: aspiration, dtype: int64
#
#  doornumber has 2 unique entries; and the top unique values are
# four    115
# two      90
# Name: doornumber, dtype: int64
#
#  carbody has 5 unique entries; and the top unique values are
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: carbody, dtype: int64
#
#  drivewheel has 3 unique entries; and the top unique values are
# fwd    120
# rwd     76
# 4wd      9
# Name: drivewheel, dtype: int64
#
#  enginelocation has 2 unique entries; and the top unique values are
# front    202
# rear       3
# Name: enginelocation, dtype: int64
#
#  enginetype has 7 unique entries; and the top unique values are
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# Name: enginetype, dtype: int64
#
#  cylindernumber has 7 unique entries; and the top unique values are
# four      159
# six        24
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# Name: cylindernumber, dtype: int64
#
#  fuelsystem has 8 unique entries; and the top unique values are
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: fuelsystem, dtype: int64

# %%
#Black = filled; white = empty
_=msno.matrix(Car.sample(Car.shape[0]))

# %%
# Extracting Car Company from the CarName as per direction in Problem 
Car['CarName'] = Car.CarName.str.split(' ',1).tolist()
Car['Brand'] = Car['CarName'].str[0]
Car['Model'] = Car['CarName'].str[1]
Car.head()
# Out:
#    car_ID  symboling                      CarName fueltype aspiration  \
# 0       1          3        [alfa-romero, giulia]      gas        std
# 1       2          3       [alfa-romero, stelvio]      gas        std
# 2       3          1  [alfa-romero, Quadrifoglio]      gas        std
# 3       4          2               [audi, 100 ls]      gas        std
# 4       5          2                [audi, 100ls]      gas        std
#
#   doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# 0        two  convertible        rwd          front       88.6  ...
# 1        two  convertible        rwd          front       88.6  ...
# 2        two    hatchback        rwd          front       94.5  ...
# 3       four        sedan        fwd          front       99.8  ...
# 4       four        sedan        4wd          front       99.4  ...
#
#    boreratio  stroke  compressionratio  horsepower peakrpm citympg  \
# 0       3.47    2.68               9.0         111    5000      21
# 1       3.47    2.68               9.0         111    5000      21
# 2       2.68    3.47               9.0         154    5000      19
# 3       3.19    3.40              10.0         102    5500      24
# 4       3.19    3.40               8.0         115    5500      18
#
#    highwaympg    price        Brand         Model
# 0          27  13495.0  alfa-romero        giulia
# 1          27  16500.0  alfa-romero       stelvio
# 2          26  16500.0  alfa-romero  Quadrifoglio
# 3          30  13950.0         audi        100 ls
# 4          22  17450.0         audi         100ls
#
# [5 rows x 28 columns]

# %%
# dropping car_ID based on business knowledge
Car = Car.drop('car_ID',axis=1)
#Car = Car.drop('CarName',axis=1)

# %%
Car.head()
# Out:
#    symboling                      CarName fueltype aspiration doornumber  \
# 0          3        [alfa-romero, giulia]      gas        std        two
# 1          3       [alfa-romero, stelvio]      gas        std        two
# 2          1  [alfa-romero, Quadrifoglio]      gas        std        two
# 3          2               [audi, 100 ls]      gas        std       four
# 4          2                [audi, 100ls]      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0  convertible        rwd          front       88.6      168.8  ...
# 1  convertible        rwd          front       88.6      168.8  ...
# 2    hatchback        rwd          front       94.5      171.2  ...
# 3        sedan        fwd          front       99.8      176.6  ...
# 4        sedan        4wd          front       99.4      176.6  ...
#
#    boreratio  stroke  compressionratio horsepower peakrpm  citympg highwaympg  \
# 0       3.47    2.68               9.0        111    5000       21         27
# 1       3.47    2.68               9.0        111    5000       21         27
# 2       2.68    3.47               9.0        154    5000       19         26
# 3       3.19    3.40              10.0        102    5500       24         30
# 4       3.19    3.40               8.0        115    5500       18         22
#
#      price        Brand         Model
# 0  13495.0  alfa-romero        giulia
# 1  16500.0  alfa-romero       stelvio
# 2  16500.0  alfa-romero  Quadrifoglio
# 3  13950.0         audi        100 ls
# 4  17450.0         audi         100ls
#
# [5 rows x 27 columns]

# %%
Car.rename(columns={ "symboling":"Symboling", "price": "Price", "fueltype": "Fueltype","carbody":"Category"}, inplace =True)

# %%
Car['Brand'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %% [markdown]
# ### Typo Error in Car Company name
#
# - maxda = mazda
# - Nissan = nissan
# - porsche = porcshce
# - toyota = toyouta
# - vokswagen = volkswagen = vw

# %%
# Renaming the typo errors in Car Company names

Car['Brand'] = Car['Brand'].replace({'maxda': 'mazda', 'nissan': 'Nissan', 'porcshce': 'porsche', 'toyouta': 'toyota', 
                            'vokswagen': 'volkswagen', 'vw': 'volkswagen'})

# %%
# changing the datatype of symboling as it is categorical variable as per dictionary file

Car['Symboling'] = Car['Symboling'].astype(str)

# %%
Car.head()
# Out:
#   Symboling                      CarName Fueltype aspiration doornumber  \
# 0         3        [alfa-romero, giulia]      gas        std        two
# 1         3       [alfa-romero, stelvio]      gas        std        two
# 2         1  [alfa-romero, Quadrifoglio]      gas        std        two
# 3         2               [audi, 100 ls]      gas        std       four
# 4         2                [audi, 100ls]      gas        std       four
#
#       Category drivewheel enginelocation  wheelbase  carlength  ...  \
# 0  convertible        rwd          front       88.6      168.8  ...
# 1  convertible        rwd          front       88.6      168.8  ...
# 2    hatchback        rwd          front       94.5      171.2  ...
# 3        sedan        fwd          front       99.8      176.6  ...
# 4        sedan        4wd          front       99.4      176.6  ...
#
#    boreratio  stroke  compressionratio horsepower peakrpm  citympg highwaympg  \
# 0       3.47    2.68               9.0        111    5000       21         27
# 1       3.47    2.68               9.0        111    5000       21         27
# 2       2.68    3.47               9.0        154    5000       19         26
# 3       3.19    3.40              10.0        102    5500       24         30
# 4       3.19    3.40               8.0        115    5500       18         22
#
#      Price        Brand         Model
# 0  13495.0  alfa-romero        giulia
# 1  16500.0  alfa-romero       stelvio
# 2  16500.0  alfa-romero  Quadrifoglio
# 3  13950.0         audi        100 ls
# 4  17450.0         audi         100ls
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Dataset 2

# %%
#read the data file
Auction = pd.read_csv('USA_cars_datasets.csv')
Auction.head()
# Out:
#    Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1           1   2899       ford       se  2011  clean vehicle  190552.0
# 2           2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3           3  25000       ford     door  2014  clean vehicle   64146.0
# 4           4  27700  chevrolet     1500  2018  clean vehicle    6654.0
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1  silver    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2  silver    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    blue    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4     red    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %%
#check the number of rows and columns in the dataframe
Auction.shape
# Out:
# (2499, 13)

# %% [markdown]
# ## CleanUp, Sanity check and removal of Data Inconsistencies

# %%
#Find number of non-null values and data type of each column in the dataframe
Auction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2499 entries, 0 to 2498
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    2499 non-null   int64
#  1   price         2499 non-null   int64
#  2   brand         2499 non-null   object
#  3   model         2499 non-null   object
#  4   year          2499 non-null   int64
#  5   title_status  2499 non-null   object
#  6   mileage       2499 non-null   float64
#  7   color         2499 non-null   object
#  8   vin           2499 non-null   object
#  9   lot           2499 non-null   int64
#  10  state         2499 non-null   object
#  11  country       2499 non-null   object
#  12  condition     2499 non-null   object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 253.9+ KB

# %%
# describe of the data
Auction.describe()
# Out:
#         Unnamed: 0         price         year       mileage           lot
# count  2499.000000   2499.000000  2499.000000  2.499000e+03  2.499000e+03
# mean   1249.000000  18767.671469  2016.714286  5.229869e+04  1.676914e+08
# std     721.543484  12116.094936     3.442656  5.970552e+04  2.038772e+05
# min       0.000000      0.000000  1973.000000  0.000000e+00  1.593488e+08
# 25%     624.500000  10200.000000  2016.000000  2.146650e+04  1.676253e+08
# 50%    1249.000000  16900.000000  2018.000000  3.536500e+04  1.677451e+08
# 75%    1873.500000  25555.500000  2019.000000  6.347250e+04  1.677798e+08
# max    2498.000000  84900.000000  2020.000000  1.017936e+06  1.678055e+08

# %% [markdown]
# Now we check whether there are any columns that have same value for all the rows

# %%
counter = 0
for this_column in Auction.columns:
    if (Auction[this_column].nunique()==1):
        print(this_column)
        counter = 1
if(counter != 1):
    print('There are no such columns having the same value for all the rows.')
# Out:
# There are no such columns having the same value for all the rows.

# %% [markdown]
# Now lets get the number of uniques values per column and their counts

# %%
#function to number of unique values and its count for all columns in a data frame
def uniq_per_col(df,count):
    for this_column in df.columns:
        print("==== ",this_column,"has",df[this_column].nunique(),"unique entries ====")
        print(df[this_column].value_counts().head(count))

# %%
uniq_per_col(Auction,5)
# Out:
# ====  Unnamed: 0 has 2499 unique entries ====
# 0       1
# 1669    1
# 1662    1
# 1663    1
# 1664    1
# Name: Unnamed: 0, dtype: int64
# ====  price has 790 unique entries ====
# 0        43
# 16500    26
# 13900    21
# 15500    19
# 15000    19
# Name: price, dtype: int64
# ====  brand has 28 unique entries ====
# ford         1235
# dodge         432
# nissan        312
# chevrolet     297
# gmc            42
# Name: brand, dtype: int64
# ====  model has 127 unique entries ====
# door       651
# f-150      219
# doors      148
# caravan    102
# mpv         87
# Name: model, dtype: int64
# ====  year has 30 unique entries ====
# 2019    892
# 2018    395
# 2017    377
# 2016    203
# 2015    196
# Name: year, dtype: int64
# ====  title_status has 2 unique entries ====
# clean vehicle        2336
# salvage insurance     163
# Name: title_status, dtype: int64
# ====  mileage has 2439 unique entries ====
# 1.0        11
# 0.0         6
# 31727.0     2
# 33808.0     2
# 21774.0     2
# Name: mileage, dtype: int64
# ====  color has 49 unique entries ====
# white     707
# black     516
# gray      395
# silver    300
# red       192
# Name: color, dtype: int64
# ====  vin has 2495 unique entries ====
#   1gnevhkw8jj148388    2
#   1gndt13s632267445    2
#   3gcrkse37ag234620    2
#   1g1al58f787159241    2
#   1fm5k8gt7kgb48943    1
# Name: vin, dtype: int64
# ====  lot has 2495 unique entries ====
# 167781794    2
# 167650636    2
# 167650663    2
# 167650632    2
# 167749575    1
# Name: lot, dtype: int64
# ====  state has 44 unique entries ====
# pennsylvania    299
# florida         246
# texas           214
# california      190
# michigan        169
# Name: state, dtype: int64
# ====  country has 2 unique entries ====
#  usa       2492
#  canada       7
# Name: country, dtype: int64
# ====  condition has 47 unique entries ====
# 2 days left      832
# 21 hours left    492
# 3 days left      137
# 14 hours left    108
# 1 days left       91
# Name: condition, dtype: int64

# %% [markdown]
# Now lets find the percentage of null values in each column

# %%
Car.isnull().sum()/len(Car)*100
# Out:
# Symboling           0.00000
# CarName             0.00000
# Fueltype            0.00000
# aspiration          0.00000
# doornumber          0.00000
# Category            0.00000
# drivewheel          0.00000
# enginelocation      0.00000
# wheelbase           0.00000
# carlength           0.00000
# carwidth            0.00000
# carheight           0.00000
# curbweight          0.00000
# enginetype          0.00000
# cylindernumber      0.00000
# enginesize          0.00000
# fuelsystem          0.00000
# boreratio           0.00000
# stroke              0.00000
# compressionratio    0.00000
# horsepower          0.00000
# peakrpm             0.00000
# citympg             0.00000
# highwaympg          0.00000
# Price               0.00000
# Brand               0.00000
# Model               0.97561
# dtype: float64

# %% [markdown]
# From the above observation it is clear that, we have a good variety of data and have eliminated various data inconsistencies that would be there. We have minimal null values in the data. Hence we can conclude that we have good data. But we still can work on the data types of object type columns.

# %%
#find number of unique values in various object type columns
count = 10
for col,col_type in Auction.dtypes.iteritems():
    if(col_type=='object'):
        print('\n',col,'has',Auction[col].nunique(),'unique entries; and the top unique values are ')
        print(Auction[col].value_counts().head(count))
# Out:
#  brand has 28 unique entries; and the top unique values are
# ford         1235
# dodge         432
# nissan        312
# chevrolet     297
# gmc            42
# jeep           30
# chrysler       18
# bmw            17
# hyundai        15
# kia            13
# Name: brand, dtype: int64
#
#  model has 127 unique entries; and the top unique values are
# door       651
# f-150      219
# doors      148
# caravan    102
# mpv         87
# fusion      65
# durango     64
# journey     61
# rogue       54
# van         46
# Name: model, dtype: int64
#
#  title_status has 2 unique entries; and the top unique values are
# clean vehicle        2336
# salvage insurance     163
# Name: title_status, dtype: int64
#
#  color has 49 unique entries; and the top unique values are
# white       707
# black       516
# gray        395
# silver      300
# red         192
# blue        151
# no_color     61
# green        24
# orange       20
# gold         19
# Name: color, dtype: int64
#
#  vin has 2495 unique entries; and the top unique values are
#   1gnevhkw8jj148388    2
#   1gndt13s632267445    2
#   3gcrkse37ag234620    2
#   1g1al58f787159241    2
#   1fm5k8gt7kgb48943    1
#   1ftew1e54kfb82591    1
#   maj6s3kl2kc287149    1
#   1fmcu9g9xeuc07694    1
#   1ftew1e54kfb48392    1
#   2fmpk4k95kbc01949    1
# Name: vin, dtype: int64
#
#  state has 44 unique entries; and the top unique values are
# pennsylvania      299
# florida           246
# texas             214
# california        190
# michigan          169
# north carolina    146
# minnesota         119
# illinois          113
# wisconsin          94
# virginia           90
# Name: state, dtype: int64
#
#  country has 2 unique entries; and the top unique values are
#  usa       2492
#  canada       7
# Name: country, dtype: int64
#
#  condition has 47 unique entries; and the top unique values are
# 2 days left      832
# 21 hours left    492
# 3 days left      137
# 14 hours left    108
# 1 days left       91
# 8 days left       82
# 17 hours left     76
# 20 hours left     67
# 9 days left       58
# 22 hours left     57
# Name: condition, dtype: int64

# %%
#Black = filled; white = empty
_=msno.matrix(Auction.sample(Auction.shape[0]))

# %% [markdown]
# The dataset includes 13 features of 2499 cars. Some of the features are important when determining the price of a car while some are redundant. For example, “vin”, “lot” and “Unnamed: 0” columns have no effect on the price. These three columns represent kind of an ID for a car. Since the dataset is taken from a website in US, I think the country column only includes “usa”. Let’s check:

# %%
Auction.country.value_counts()
# Out:
#  usa       2492
#  canada       7
# Name: country, dtype: int64

# %% [markdown]
# Not all but overwhelming majority is “usa” so there is no point in using “country” column as a feature in our model. So the columns that we will not use in the model are "Unnamed, vin, lot, country" so lets drop them.

# %%
Auction.drop(['Unnamed: 0','vin', 'lot','country'], axis=1, inplace=True)
Auction.head()
# Out:
#    price      brand    model  year   title_status   mileage   color  \
# 0   6300     toyota  cruiser  2008  clean vehicle  274117.0   black
# 1   2899       ford       se  2011  clean vehicle  190552.0  silver
# 2   5350      dodge      mpv  2018  clean vehicle   39590.0  silver
# 3  25000       ford     door  2014  clean vehicle   64146.0    blue
# 4  27700  chevrolet     1500  2018  clean vehicle    6654.0     red
#
#         state      condition
# 0  new jersey   10 days left
# 1   tennessee    6 days left
# 2     georgia    2 days left
# 3    virginia  22 hours left
# 4     florida  22 hours left

# %%
Auction.title_status.value_counts()
# Out:
# clean vehicle        2336
# salvage insurance     163
# Name: title_status, dtype: int64

# %%
Auction['model'].unique()
# Out:
# array(['cruiser', 'se', 'mpv', 'door', '1500', 'pk', 'malibu', 'coupe',
#        'wagon', 'forte', 'encore', 'sorento', 'doors', 'chassis', 'q70',
#        'camaro', 'convertible', 'vans', 'srw', 'compass', 'enclave',
#        '300', 'cherokee', 'pacifica', 'x3', 'equinox', 'challenger', 'm',
#        'colorado', 'focus', 'durango', 'escape', 'charger', 'explorer',
#        'f-150', '3500', 'caravan', 'van', 'dart', '2500', 'esv',
#        'cutaway', 'el', 'edge', 'series', 'flex', 'srx', 'cab', 'pickup',
#        'vehicl', 'trax', 'tahoe', 'suburban', 'cargo', 'drw', 'fiesta',
#        'impala', 'soul', 'elantra', 'pioneer', 'trail', 'traverse',
#        'country', 'sundance', 'road/street', 'nautilus', 'gx', 'q5',
#        'gle', 'sportage', '5', 'sport', 'discovery', 'acadia', 'ghibli',
#        'glc', 'e-class', 'truck', 'utility', 'limited', 'sl-class',
#        'cx-3', '2500hd', 'sonic', 'corvette', 'mdx', 'xt5', 'fusion',
#        'mustang', 'passenger', 'volt', 'spark', 'cruze', 'ld', 'journey',
#        'transit', 'ranger', 'taurus', 'max', 'energi', 'expedition',
#        'bus', 'ecosport', 'f-750', 'd', 'dr', 'hybrid', 'suv', 'connect',
#        'f-650', 'sentra', 'altima', 'frontier', 'rogue', 'maxima',
#        'versa', 'note', 'armada', 'pathfinder', 'titan', 'sedan', 'juke',
#        'murano', 'xterra', 'kicks', 'xd', 'nvp'], dtype=object)

# %%
def generalise(data):
    dic = {"sedan":["cruiser","forte", "q70", "camaro", "300", "challenger", "focus", "charger", "dart","el", "series", "vehicle", "fiesta", "impala", "elantra", "ghibli", "e-class", "versa", "fusion", "sonic", "cruze", "energi", "Taurus", "hybrid", "sentra",
            "altima", "maxima", "sentra", "versa","sedan","charger","dart","vehicl","impala"],
           "truck" :["1500", "colorado","pickup", "f-150", "3500", "2500", "2500hd", "ranger", "f-750", "f-650", "frontier", "d", "dr", "titan", "utility", "limited", "ld","truck"], 
           "sport car":['sl-class','sport'],                        
           "convertible":["malibu","convertible"], 
           "hatchback":["Mpv","mpv" "volt", "spark", "note", "max"], 
           "suv":["se", "encore", "sorento", "compass", "enclave", "cherokee", "x3", "equinox", "durango", "escape", "explorer", "esv", "edge", "srx", "trax", "tahoe", 
                "suburban", "soul", "traverse", "nautilus", "gx", "q5", "gle", "sportage", "sport", "discovery", "acadia", "glc", "juke", "utility", "xt5", "mdx", "cx-3", 
                "expedition", "ecosport", "murano","durango", "rogue", "armada", "pathfinder", "xd", "kicks", "murano", "xterra","ecosport", "journey", "passenger","suv"],
           "wagon":["flex", "transit","wagon"], 
            "door":["Doors","door","doors"],
           "coupe":["m", "5", "corvette", "mustang","coupe","camaro","challenger"],
           "vans":["pacifica", "caravan", "connect", "nvp", "passenger","mpv","vans","van"],
           "cargo":["bus","cargo","cutaway"],
           "trailers":["pioneer", "trail", "country", "sundance","trailer"],
            "motorcycle":["road/street"],
           "pk":["pk"],
           "swr":["swr"],
           "cab":["cab"]
}
    Category = []
    for d in data:
        done = False
        for categ in dic.keys():
            if d in dic[categ]:
                Category.append(categ)
                done = True
                break
        if not done:
            Category.append("NA")
    return Category

Auction['Category'] = generalise(Auction['model'])
Auction.head()
# Out:
#    price      brand    model  year   title_status   mileage   color  \
# 0   6300     toyota  cruiser  2008  clean vehicle  274117.0   black
# 1   2899       ford       se  2011  clean vehicle  190552.0  silver
# 2   5350      dodge      mpv  2018  clean vehicle   39590.0  silver
# 3  25000       ford     door  2014  clean vehicle   64146.0    blue
# 4  27700  chevrolet     1500  2018  clean vehicle    6654.0     red
#
#         state      condition Category
# 0  new jersey   10 days left    sedan
# 1   tennessee    6 days left      suv
# 2     georgia    2 days left     vans
# 3    virginia  22 hours left     door
# 4     florida  22 hours left    truck

# %%
Auction.rename(columns={ "price":"AuctionPrice", "brand": "Brand", "model": "Model", "year": "Year", "title_status": "Title_Status", "mileage": "Mileage", "color": "Color", "state": "State", "condition": "Condition", "country":"Country"}, inplace =True)

# %%
Auction.head()
# Out:
#    AuctionPrice      Brand    Model  Year   Title_Status   Mileage   Color  \
# 0          6300     toyota  cruiser  2008  clean vehicle  274117.0   black
# 1          2899       ford       se  2011  clean vehicle  190552.0  silver
# 2          5350      dodge      mpv  2018  clean vehicle   39590.0  silver
# 3         25000       ford     door  2014  clean vehicle   64146.0    blue
# 4         27700  chevrolet     1500  2018  clean vehicle    6654.0     red
#
#         State      Condition Category
# 0  new jersey   10 days left    sedan
# 1   tennessee    6 days left      suv
# 2     georgia    2 days left     vans
# 3    virginia  22 hours left     door
# 4     florida  22 hours left    truck

# %% [markdown]
# ## Merge the Dataset

# %%
Car_Data = pd.merge(Auction, Car, how ='inner', on= ['Brand'])

# %%
Car_Data.head(10)
# Out:
#    AuctionPrice   Brand  Model_x  Year   Title_Status   Mileage  Color  \
# 0          6300  toyota  cruiser  2008  clean vehicle  274117.0  black
# 1          6300  toyota  cruiser  2008  clean vehicle  274117.0  black
# 2          6300  toyota  cruiser  2008  clean vehicle  274117.0  black
# 3          6300  toyota  cruiser  2008  clean vehicle  274117.0  black
# 4          6300  toyota  cruiser  2008  clean vehicle  274117.0  black
# 5          6300  toyota  cruiser  2008  clean vehicle  274117.0  black
# 6          6300  toyota  cruiser  2008  clean vehicle  274117.0  black
# 7          6300  toyota  cruiser  2008  clean vehicle  274117.0  black
# 8          6300  toyota  cruiser  2008  clean vehicle  274117.0  black
# 9          6300  toyota  cruiser  2008  clean vehicle  274117.0  black
#
#         State     Condition Category_x  ... fuelsystem boreratio stroke  \
# 0  new jersey  10 days left      sedan  ...       2bbl      3.05   3.03
# 1  new jersey  10 days left      sedan  ...       2bbl      3.05   3.03
# 2  new jersey  10 days left      sedan  ...       2bbl      3.05   3.03
# 3  new jersey  10 days left      sedan  ...       2bbl      3.05   3.03
# 4  new jersey  10 days left      sedan  ...       2bbl      3.05   3.03
# 5  new jersey  10 days left      sedan  ...       2bbl      3.05   3.03
# 6  new jersey  10 days left      sedan  ...       2bbl      3.19   3.03
# 7  new jersey  10 days left      sedan  ...       2bbl      3.19   3.03
# 8  new jersey  10 days left      sedan  ...        idi      3.27   3.35
# 9  new jersey  10 days left      sedan  ...        idi      3.27   3.35
#
#   compressionratio horsepower peakrpm citympg highwaympg   Price  \
# 0              9.0         62    4800      35         39  5348.0
# 1              9.0         62    4800      31         38  6338.0
# 2              9.0         62    4800      31         38  6488.0
# 3              9.0         62    4800      31         37  6918.0
# 4              9.0         62    4800      27         32  7898.0
# 5              9.0         62    4800      27         32  8778.0
# 6              9.0         70    4800      30         37  6938.0
# 7              9.0         70    4800      30         37  7198.0
# 8             22.5         56    4500      34         36  7898.0
# 9             22.5         56    4500      38         47  7788.0
#
#              Model_y
# 0     corona mark ii
# 1             corona
# 2       corolla 1200
# 3     corona hardtop
# 4  corolla 1600 (sw)
# 5             carina
# 6            mark ii
# 7       corolla 1200
# 8             corona
# 9            corolla
#
# [10 rows x 36 columns]

# %%
Car_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5272 entries, 0 to 5271
# Data columns (total 36 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   AuctionPrice      5272 non-null   int64
#  1   Brand             5272 non-null   object
#  2   Model_x           5272 non-null   object
#  3   Year              5272 non-null   int64
#  4   Title_Status      5272 non-null   object
#  5   Mileage           5272 non-null   float64
#  6   Color             5272 non-null   object
#  7   State             5272 non-null   object
#  8   Condition         5272 non-null   object
#  9   Category_x        5272 non-null   object
#  10  Symboling         5272 non-null   object
#  11  CarName           5272 non-null   object
#  12  Fueltype          5272 non-null   object
#  13  aspiration        5272 non-null   object
#  14  doornumber        5272 non-null   object
#  15  Category_y        5272 non-null   object
#  16  drivewheel        5272 non-null   object
#  17  enginelocation    5272 non-null   object
#  18  wheelbase         5272 non-null   float64
#  19  carlength         5272 non-null   float64
#  20  carwidth          5272 non-null   float64
#  21  carheight         5272 non-null   float64
#  22  curbweight        5272 non-null   int64
#  23  enginetype        5272 non-null   object
#  24  cylindernumber    5272 non-null   object
#  25  enginesize        5272 non-null   int64
#  26  fuelsystem        5272 non-null   object
#  27  boreratio         5272 non-null   float64
#  28  stroke            5272 non-null   float64
#  29  compressionratio  5272 non-null   float64
#  30  horsepower        5272 non-null   int64
#  31  peakrpm           5272 non-null   int64
#  32  citympg           5272 non-null   int64
#  33  highwaympg        5272 non-null   int64
#  34  Price             5272 non-null   float64
#  35  Model_y           5272 non-null   object
# dtypes: float64(9), int64(8), object(19)
# memory usage: 1.5+ MB

# %%
Car_Data.drop(['Condition','stroke','horsepower','citympg',
               'highwaympg','cylindernumber'],axis=1,inplace=True)
               

Car_Data.head()
# Out:
#    AuctionPrice   Brand  Model_x  Year   Title_Status   Mileage  Color  \
# 0          6300  toyota  cruiser  2008  clean vehicle  274117.0  black
# 1          6300  toyota  cruiser  2008  clean vehicle  274117.0  black
# 2          6300  toyota  cruiser  2008  clean vehicle  274117.0  black
# 3          6300  toyota  cruiser  2008  clean vehicle  274117.0  black
# 4          6300  toyota  cruiser  2008  clean vehicle  274117.0  black
#
#         State Category_x Symboling  ... carheight curbweight enginetype  \
# 0  new jersey      sedan         1  ...      54.5       1985        ohc
# 1  new jersey      sedan         1  ...      54.5       2040        ohc
# 2  new jersey      sedan         1  ...      54.5       2015        ohc
# 3  new jersey      sedan         0  ...      59.1       2280        ohc
# 4  new jersey      sedan         0  ...      59.1       2290        ohc
#
#   enginesize fuelsystem boreratio compressionratio  peakrpm   Price  \
# 0         92       2bbl      3.05              9.0     4800  5348.0
# 1         92       2bbl      3.05              9.0     4800  6338.0
# 2         92       2bbl      3.05              9.0     4800  6488.0
# 3         92       2bbl      3.05              9.0     4800  6918.0
# 4         92       2bbl      3.05              9.0     4800  7898.0
#
#              Model_y
# 0     corona mark ii
# 1             corona
# 2       corolla 1200
# 3     corona hardtop
# 4  corolla 1600 (sw)
#
# [5 rows x 30 columns]

# %%
Car_Data.drop(['wheelbase', 'Symboling','carlength','carwidth','carheight',
               'curbweight','compressionratio'],axis=1,inplace=True)
               

Car_Data.head()
# Out:
#    AuctionPrice   Brand  Model_x  Year   Title_Status   Mileage  Color  \
# 0          6300  toyota  cruiser  2008  clean vehicle  274117.0  black
# 1          6300  toyota  cruiser  2008  clean vehicle  274117.0  black
# 2          6300  toyota  cruiser  2008  clean vehicle  274117.0  black
# 3          6300  toyota  cruiser  2008  clean vehicle  274117.0  black
# 4          6300  toyota  cruiser  2008  clean vehicle  274117.0  black
#
#         State Category_x                      CarName  ... Category_y  \
# 0  new jersey      sedan     [toyota, corona mark ii]  ...  hatchback
# 1  new jersey      sedan             [toyota, corona]  ...  hatchback
# 2  new jersey      sedan       [toyota, corolla 1200]  ...  hatchback
# 3  new jersey      sedan     [toyota, corona hardtop]  ...      wagon
# 4  new jersey      sedan  [toyota, corolla 1600 (sw)]  ...      wagon
#
#   drivewheel enginelocation enginetype enginesize fuelsystem boreratio  \
# 0        fwd          front        ohc         92       2bbl      3.05
# 1        fwd          front        ohc         92       2bbl      3.05
# 2        fwd          front        ohc         92       2bbl      3.05
# 3        fwd          front        ohc         92       2bbl      3.05
# 4        4wd          front        ohc         92       2bbl      3.05
#
#    peakrpm   Price            Model_y
# 0     4800  5348.0     corona mark ii
# 1     4800  6338.0             corona
# 2     4800  6488.0       corolla 1200
# 3     4800  6918.0     corona hardtop
# 4     4800  7898.0  corolla 1600 (sw)
#
# [5 rows x 23 columns]

# %%
Car_Data.drop(['CarName'],axis=1,inplace=True)
Car_Data.head()
# Out:
#    AuctionPrice   Brand  Model_x  Year   Title_Status   Mileage  Color  \
# 0          6300  toyota  cruiser  2008  clean vehicle  274117.0  black
# 1          6300  toyota  cruiser  2008  clean vehicle  274117.0  black
# 2          6300  toyota  cruiser  2008  clean vehicle  274117.0  black
# 3          6300  toyota  cruiser  2008  clean vehicle  274117.0  black
# 4          6300  toyota  cruiser  2008  clean vehicle  274117.0  black
#
#         State Category_x Fueltype  ... Category_y drivewheel enginelocation  \
# 0  new jersey      sedan      gas  ...  hatchback        fwd          front
# 1  new jersey      sedan      gas  ...  hatchback        fwd          front
# 2  new jersey      sedan      gas  ...  hatchback        fwd          front
# 3  new jersey      sedan      gas  ...      wagon        fwd          front
# 4  new jersey      sedan      gas  ...      wagon        4wd          front
#
#   enginetype enginesize fuelsystem  boreratio peakrpm   Price  \
# 0        ohc         92       2bbl       3.05    4800  5348.0
# 1        ohc         92       2bbl       3.05    4800  6338.0
# 2        ohc         92       2bbl       3.05    4800  6488.0
# 3        ohc         92       2bbl       3.05    4800  6918.0
# 4        ohc         92       2bbl       3.05    4800  7898.0
#
#              Model_y
# 0     corona mark ii
# 1             corona
# 2       corolla 1200
# 3     corona hardtop
# 4  corolla 1600 (sw)
#
# [5 rows x 22 columns]

# %%
Car_Data['Year'].dtype
# Out:
# dtype('int64')

# %%
Car_Data['Brand'].unique()
# Out:
# array(['toyota', 'dodge', 'chevrolet', 'buick', 'bmw', 'mazda', 'honda',
#        'jaguar', 'audi'], dtype=object)

# %% [markdown]
# ## Visualizations

# %%
plot = sns.displot(data = Car_Data, x= 'Year', kind = 'hist', height=7 ,aspect=2)
plot.ax.set_xticks(Car_Data['Year'].unique())
plot.ax.tick_params(axis = 'x', labelrotation = 90)
plot.ax.set_title("Number of Car Purchased per Year")
'''
This shows that the number of car purchased increased over years, and the purchase peaked in 2019. Decreased in 2020.
'''
# Out:
# '\nThis shows that the number of car purchased increased over years, and the purchase peaked in 2019. Decreased in 2020.\n'

# %%
plot = sns.displot(data = Car_Data, x= 'Brand', kind = 'hist', height=3 ,aspect=2)
plot.ax.set_xticks(Car_Data['Brand'].unique())
plot.ax.tick_params(axis = 'x', labelrotation = 90)
plot.ax.set_title("Number of Car Brands")
'''
Dodge is the most popular brand in the auction, followed by Chevrolet.
'''
# Out:
# '\nDodge is the most popular brand in the auction, followed by Chevrolet.\n'

# %%
plot = sns.displot(data = Car_Data, x= 'Category_x', kind = 'hist', height=3 ,aspect=2)
plot.ax.tick_params(axis = 'x', labelrotation = 90)
plot.ax.set_title("Types of car in the Auction")
'''
Most popular is SUV, Vans and Sedans. As this is the auction data, their's also Car's door available

'''
# Out:
# "\nMost popular is SUV, Vans and Sedans. As this is the auction data, their's also Car's door available\n\n"

# %%
plot = sns.scatterplot(x= Car_Data['Model_x'], y = Car_Data['Category_x'], hue = Car_Data['Brand'], alpha = 0.1, sizes=(5, 5))
plot.axes.tick_params(axis = 'x', labelrotation = 90)
fig = plt.gcf()
fig.set_size_inches(12, 12)
plot.axes.set_title("Popular Brand and Model")
'''
SUV, Sedan, and Trucks are popular in auctions
'''
# Out:
# '\nSUV, Sedan, and Trucks are popular in auctions\n'

# %%
plot = sns.scatterplot(x= Car_Data['Mileage'], y = Car_Data['Year'], hue = Car_Data['Brand'], alpha = 0.1, sizes=(5, 5))
plot.axes.tick_params(axis = 'x', labelrotation = 90)
fig = plt.gcf()
fig.set_size_inches(12, 12)
plot.axes.set_title("Mileage and Purchased Year")
'''
Most of the Cars are purchased only few years back,and is having less the 100000 Mileage.
Chevrolet Model is purchased in recent years, between 2015 to 2020
'''
# Out:
# '\nMost of the Cars are purchased only few years back,and is having less the 100000 Mileage.\nChevrolet Model is purchased in recent years, between 2015 to 2020\n'

# %%
plot = sns.displot(Car_Data, x="Brand", y="Category_x", cbar = True, aspect = 2)
plot.ax.tick_params(axis = 'x', labelrotation = 90)
plot.ax.set_title("Primary factor for every Collision type")
'''
It seems thats Car Brand Dodge is popular among Sedan, Vans, SUV,and also doors.
'''
# Out:
# '\nIt seems thats Car Brand Dodge is popular among Sedan, Vans, SUV,and also doors.\n'

# %%
plot = sns.displot(data = Car_Data, x= 'State', kind = 'hist', height=3 ,aspect=3)
plot.ax.set_xticks(Car_Data['State'].unique())
plot.ax.tick_params(axis = 'x', labelrotation = 90)
plot.ax.set_title("Auction at states")
'''
Pennsylvania and North Carolina conducts the most Auction
'''
# Out:
# '\nPennsylvania and North Carolina conducts the most Auction\n'

# %%
plot = sns.displot(Car_Data, x="State", y="Brand", cbar = True, aspect = 2)
plot.ax.tick_params(axis = 'x', labelrotation = 90)
plot.ax.set_title("Primary factor for every Collision type")
# Out:
# Text(0.5, 1.0, 'Primary factor for every Collision type')

# %%
# is this understandable? what do you understand from this graph?
plot= sns.displot(data=Car_Data, kind="kde", x="Price", hue = "Brand", aspect=2, alpha=0.5)
plot.ax.grid()

# %%
plot= sns.displot(data=Car_Data, kind="kde", x="AuctionPrice", hue = "Brand", aspect=2, alpha=0.5)
plot.ax.grid()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %%
multiple_grouped = Car_Data\
    .groupby(['Brand','Category_x']) \
    .agg({'Price':'mean','AuctionPrice':'mean'})

multiple_grouped
# Out:
#                               Price  AuctionPrice
# Brand     Category_x
# audi      coupe        17859.166714  36400.000000
#           door         17859.166714     12.500000
#           suv          17859.166714  19500.000000
# bmw       coupe        26118.750000  27662.500000
#           door         26118.750000   9725.000000
#           sedan        26118.750000  36962.500000
#           suv          26118.750000  24550.000000
# buick     door         33647.000000  18575.625000
#           suv          33647.000000  21540.000000
# chevrolet NA            6007.000000  16550.000000
#           cab           6007.000000  10440.000000
#           cargo         6007.000000  16100.000000
#           convertible   6007.000000  13533.583333
#           coupe         6007.000000  30717.142857
#           door          6007.000000  12314.212121
#           hatchback     6007.000000   7200.000000
#           pk            6007.000000   7300.000000
#           sedan         6007.000000  16144.565217
#           suv           6007.000000  24155.000000
#           truck         6007.000000  24388.277778
#           vans          6007.000000  16566.176471
# dodge     coupe         7875.444444  10400.000000
#           door          7875.444444  10308.241379
#           pk            7875.444444   1400.000000
#           sedan         7875.444444  24685.425287
#           suv           7875.444444  22605.200000
#           truck         7875.444444   9366.666667
#           vans          7875.444444  13842.343750
# honda     door          8184.692308   4540.000000
#           vans          8184.692308   9302.500000
# jaguar    door         34600.000000   2800.000000
# mazda     door         10652.882353      0.000000
#           suv          10652.882353  16000.000000
# toyota    sedan         9885.812500   6300.000000

# %%
plot = sns.scatterplot(x= Car_Data['Year'], y = Car_Data['AuctionPrice'], hue = Car_Data['Brand'], alpha = 0.1, sizes=(900, 900))
plot.axes.tick_params(axis = 'x', labelrotation = 90)
fig = plt.gcf()
fig.set_size_inches(12, 12)
plot.axes.set_title("Popular Brand and Model")
# Out:
# Text(0.5, 1.0, 'Popular Brand and Model')

# %%
multiple_grouped = Car_Data\
    .groupby(['Brand','Category_x','Year']) \
    .agg({'Price':'mean','AuctionPrice':'mean'})

multiple_grouped
# Out:
#                                Price  AuctionPrice
# Brand  Category_x Year
# audi   coupe      2015  17859.166714       36400.0
#        door       2005  17859.166714           0.0
#                   2008  17859.166714          25.0
#        suv        2017  17859.166714       19500.0
# bmw    coupe      2008  26118.750000        1825.0
# ...                              ...           ...
# honda  vans       2017   8184.692308        6900.0
# jaguar door       2019  34600.000000        2800.0
# mazda  door       2009  10652.882353           0.0
#        suv        2016  10652.882353       16000.0
# toyota sedan      2008   9885.812500        6300.0
#
# [134 rows x 2 columns]

# %%
sns.pairplot(Car_Data)

# %%
grouped_by_Brand = Car_Data.groupby('Brand').agg(
    #Model = ('Model_x', 'count') , 
    Brand_Price= ('Price', 'mean') ,
    Brand_Auction = ('AuctionPrice', 'mean')
    )
grouped_by_Brand
# Out:
#             Brand_Price  Brand_Auction
# Brand
# audi       17859.166714   13981.250000
# bmw        26118.750000   26397.058824
# buick      33647.000000   19715.769231
# chevrolet   6007.000000   18669.952862
# dodge       7875.444444   17781.988426
# honda       8184.692308    6127.500000
# jaguar     34600.000000    2800.000000
# mazda      10652.882353    8000.000000
# toyota      9885.812500    6300.000000

# %%
plot = sns.catplot(x='Category_x', y='Price',kind = 'bar', data = Car_Data)
plot.ax.tick_params(axis = 'x', labelrotation = 90)
'''
Coupe has the highest price with $140,000
'''
# Out:
# '\nCoupe has the highest price with $140,000\n'

# %%
plot = sns.catplot(x='Category_x', y='AuctionPrice',kind = 'bar', data = Car_Data)
plot.ax.tick_params(axis = 'x', labelrotation = 90)

# %%
plt.figure(figsize = (20,12))

plt.subplot(3,3,1)
sns.boxplot(x = 'aspiration', y = 'Price', data = Car_Data)

plt.subplot(3,3,2)
sns.boxplot(x = 'Category_y', y = 'Price', data = Car_Data)

plt.subplot(3,3,3)
sns.boxplot(x = 'drivewheel', y = 'Price', data = Car_Data)

plt.subplot(3,3,4)
sns.boxplot(x = 'enginelocation', y = 'Price', data = Car_Data)

plt.subplot(3,3,5)
sns.boxplot(x = 'enginetype', y = 'Price', data = Car_Data)

plt.subplot(3,3,6)
sns.boxplot(x = 'fuelsystem', y = 'Price', data = Car_Data)

'''
A Rear-Wheel Drive car uses two of the four wheels to develop forward momentum.
'''
# Out:
# '\nA Rear-Wheel Drive car uses two of the four wheels to develop forward momentum.\n'

# %%
plt.figure(figsize = (20,12))
sns.boxplot(x = 'Brand', y = 'Price', data =Car_Data)
'''
The brands with the most expensive vehicles in the dataset belong to Bmw,Buick,Jaguar 

'''
# Out:
# '\nThe brands with the most expensive vehicles in the dataset belong to Bmw,Buick,Jaguar \n\n'

# %% [markdown]
# # Observations
# - Most cars are purchased in 2019.
# - Popular Brand for auctions are Dodge, and chevrolet. The brands such as Buick, bmw, mazda, jaguar, audi are less common in auction.
# - Most popular is SUV, Vans and Sedans. As this is the auction data, their's also Car's door available
# - SUV, Sedan, and Trucks are popular in auctions
# - It seems thats Car Brand Dodge is popular among Sedan, Vans, SUV,and also doors.
# - Most of the Cars are purchased only few years back,and is having less the 100000 Mileage.
#   Chevrolet Model is purchased in recent years, between 2015 to 2020
